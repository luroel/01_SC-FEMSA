# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lectura de datos del archivo Storecheck_Enfriador_Respeto_Distribuidores_data.xlsm, hoja Comportamiento Enfriadores Geo
df_storecheck = pd.read_excel('/Users/luigi/Documents/DataScience_REMOTEdata_Github/01_SC-FEMSA/data/Storecheck_Enfriador_Respeto_Distribuidores_data.xlsm', sheet_name='Comportamiento Enfriadores Geo')
df_storecheck.head(7)
# Out:
#    Zona       Categoría  Mes 1  Mes 2  Vs MA
# 0     1  Levantamientos  466.0  463.0   -3.0
# 1     2  Levantamientos  385.0  381.0   -4.0
# 2     3  Levantamientos  727.0  738.0   11.0
# 3     4  Levantamientos  414.0  413.0   -1.0
# 4     5  Levantamientos  362.0  361.0   -1.0
# 5     6  Levantamientos  417.0  410.0   -7.0
# 6     7  Levantamientos  153.0  158.0    5.0

# %%
# Total de elementos Mes 1 por Categoría Levantamientos
levantamientos_mes1 = df_storecheck[(df_storecheck['Categoría'] == 'Levantamientos')]['Mes 1'].sum()
# Total de elementos Mes 2 por Categoría Levantamientos
levantamientos_mes2 = df_storecheck[(df_storecheck['Categoría'] == 'Levantamientos')]['Mes 2'].sum()
# Total elementos vs MA Levantamientos
levantamientos_vsma = df_storecheck[(df_storecheck['Categoría'] == 'Levantamientos')]['Vs MA'].sum()
print(f"Total Levantamientos Mes 1: {levantamientos_mes1}")
print(f"Total Levantamientos Mes 2: {levantamientos_mes2}")
print(f"Total Vs MA Levantamientos: {levantamientos_vsma}")
# Out:
# Total Levantamientos Mes 1: 2924.0
# Total Levantamientos Mes 2: 2924.0
# Total Vs MA Levantamientos: 0.0

# %%
# Total de elementos Mes 1 por Categoría Refrigeradores
refrigeradores_mes1 = df_storecheck[(df_storecheck['Categoría'] == 'Refrigeradores')]['Mes 1'].sum()
# Total de elementos Mes 2 por Categoría Refrigeradores
refrigeradores_mes2 = df_storecheck[(df_storecheck['Categoría'] == 'Refrigeradores')]['Mes 2'].sum()
# Total elementos vs MA Refrigeradores
refrigeradores_vsma = df_storecheck[(df_storecheck['Categoría'] == 'Refrigeradores')]['Vs MA'].sum()
print(f"Total Refrigeradores Mes 1: {refrigeradores_mes1}")
print(f"Total Refrigeradores Mes 2: {refrigeradores_mes2}")
print(f"Total Vs MA Refrigeradores: {refrigeradores_vsma}")
# Out:
# Total Refrigeradores Mes 1: 3500.0
# Total Refrigeradores Mes 2: 3453.0
# Total Vs MA Refrigeradores: -47.0

# %%
# Total de elementos Mes 1 por Categoría Lleno
lleno_mes1 = df_storecheck[(df_storecheck['Categoría'] == 'Lleno')]['Mes 1'].sum()
# Total de elementos Mes 2 por Categoría Lleno
lleno_mes2 = df_storecheck[(df_storecheck['Categoría'] == 'Lleno')]['Mes 2'].sum()
# Total elementos vs MA Lleno
lleno_vsma = df_storecheck[(df_storecheck['Categoría'] == 'Lleno')]['Vs MA'].sum()
print(f"Total Llenos Mes 1: {lleno_mes1}")
print(f"Total Llenos Mes 2: {lleno_mes2}")
print(f"Total Vs MA Llenos: {lleno_vsma}")
# Out:
# Total Llenos Mes 1: 3214.0
# Total Llenos Mes 2: 3080.0
# Total Vs MA Llenos: -134.0

# %%
# Total de elementos Mes 1 por Categoría Inavasiones a Refrigerador
invasionesrefrigerador_mes1 = df_storecheck[(df_storecheck['Categoría'] == 'Invasiones a refrigerador')]['Mes 1'].sum()
# Total de elementos Mes 2 por Categoría Inavasiones a Refrigerador
invasionesrefrigerador_mes2 = df_storecheck[(df_storecheck['Categoría'] == 'Invasiones a refrigerador')]['Mes 2'].sum()
# Total elementos vs MA Inavasiones a Refrigerador
invasionesrefrigerador_vsma = df_storecheck[(df_storecheck['Categoría'] == 'Invasiones a refrigerador')]['Vs MA'].sum()
print(f"Total Invasiones a Refrigerador Mes 1: {invasionesrefrigerador_mes1}")
print(f"Total Invasiones a Refrigerador Mes 2: {invasionesrefrigerador_mes2}")
print(f"Total Vs MA Invasiones a Refrigerador: {invasionesrefrigerador_vsma}")
# Out:
# Total Invasiones a Refrigerador Mes 1: 478.0
# Total Invasiones a Refrigerador Mes 2: 595.0
# Total Vs MA Invasiones a Refrigerador: 117.0

# %%
# Total de elementos Mes 1 por Categoría Porcentaje refris invadidos
Porcentaje_Invadidos_mes1 = df_storecheck[(df_storecheck['Categoría'] == 'Porcentaje refris invadidos (%)')]['Mes 1'].sum()
# Total de elementos Mes 2 por Categoría Porcentaje refris invadidos
Porcentaje_Invadidos_mes2 = df_storecheck[(df_storecheck['Categoría'] == 'Porcentaje refris invadidos (%)')]['Mes 2'].sum()
# Total elementos vs MA Porcentaje refris invadidos
Porcentaje_Invadidos_vsma = df_storecheck[(df_storecheck['Categoría'] == 'Porcentaje refris invadidos (%)')]['Vs MA'].sum()
print(f"Total Porcentaje refris invadidos Mes 1: {Porcentaje_Invadidos_mes1}%")
print(f"Total Porcentaje refris invadidos Mes 2: {Porcentaje_Invadidos_mes2}%")
print(f"Total Vs MA Porcentaje refris Invadidos: {Porcentaje_Invadidos_vsma}%")
# Out:
# Total Porcentaje refris invadidos Mes 1: 84.99656199836505%
# Total Porcentaje refris invadidos Mes 2: 108.389052558042%
# Total Vs MA Porcentaje refris Invadidos: 23.39249055967693%

# %%
# Revisión de valores Porcentaje Refris Invadidos
rows_porcentaje_refris_invadidos = df_storecheck[df_storecheck['Categoría'] == 'Porcentaje refris invadidos (%)']
print(rows_porcentaje_refris_invadidos)
# Out:
#     Zona                        Categoría      Mes 1      Mes 2      Vs MA
# 28     1  Porcentaje refris invadidos (%)   4.262295  12.438625   8.176330
# 29     2  Porcentaje refris invadidos (%)  15.668203  19.294118   3.625915
# 30     3  Porcentaje refris invadidos (%)  22.368421  24.369748   2.001327
# 31     4  Porcentaje refris invadidos (%)  10.536779  20.781893  10.245114
# 32     5  Porcentaje refris invadidos (%)   5.555556   6.038647   0.483092
# 33     6  Porcentaje refris invadidos (%)  21.917808  19.795918  -2.121890
# 34     7  Porcentaje refris invadidos (%)   4.687500   5.670103   0.982603

# %%
# Verificando el tipo de dato que tienen mis filas de Categoría Porcentaje de refris invadidos
rows_porcentaje_refris_invadidos.dtypes
# Out:
# Zona           int64
# Categoría     object
# Mes 1        float64
# Mes 2        float64
# Vs MA        float64
# dtype: object

# %%
# Detectar valores nulos de Categoría Porcentaje de refris invadidos
rows_porcentaje_refris_invadidos.isnull()
# Out:
#      Zona  Categoría  Mes 1  Mes 2  Vs MA
# 28  False      False  False  False  False
# 29  False      False  False  False  False
# 30  False      False  False  False  False
# 31  False      False  False  False  False
# 32  False      False  False  False  False
# 33  False      False  False  False  False
# 34  False      False  False  False  False

# %%
# Total de elementos Mes 1 por Categoría Invasión visible
Invasion_Visible_mes1 = df_storecheck[(df_storecheck['Categoría'] == 'Invasión visible')]['Mes 1'].sum()
# Total de elementos Mes 2 por Categoría Invasión visible
Invasion_Visible_mes2 = df_storecheck[(df_storecheck['Categoría'] == 'Invasión visible')]['Mes 2'].sum()
# Total elementos vs MA Invasión visible
Invasion_Visible_vsma = df_storecheck[(df_storecheck['Categoría'] == 'Invasión visible')]['Vs MA'].sum()
print(f"Total Invasión Visible Mes 1: {Invasion_Visible_mes1}")
print(f"Total Invasión Visible Mes 2: {Invasion_Visible_mes2}")
print(f"Total Vs MA Invasión Visible: {Invasion_Visible_vsma}")
# Out:
# Total Invasión Visible Mes 1: 422.0
# Total Invasión Visible Mes 2: 539.0
# Total Vs MA Invasión Visible: 117.0

# %% [markdown]
# # Refrigeradores invadidos vs. Mes
# ### Aumento significativo de las invasiones a refrigeradores de un mes a otro en todas las zonas.

# %%
# Grafico de barras - Total de Invasiones x Mes
mes = ['Mes 1', 'Mes 2']
total_invasiones_mensuales = [invasionesrefrigerador_mes1, invasionesrefrigerador_mes2]
plt.bar(mes, total_invasiones_mensuales, color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Total de Invasiones')
plt.title('Total de Invasiones por Mes (Zona 1-7)')
# Out:
# Text(0.5, 1.0, 'Total de Invasiones por Mes (Zona 1-7)')

# %%
# barplot - Total de Refris Invadidos x Mes vs. % de Refris Invadidos (zona 1-7)
porcentaje_invasiones_mensuales = [Porcentaje_Invadidos_mes1, Porcentaje_Invadidos_mes2]
bar_width = 0.35
x = np.arange(len(mes))

# Grouped Bar Plot
plt.bar(x - bar_width/2, total_invasiones_mensuales, bar_width, label='Total Invasiones Mensuales (Zona 1-7)', color='skyblue')
plt.bar(x + bar_width/2, porcentaje_invasiones_mensuales, bar_width, label='Porcentaje Invasiones Mensuales (%) (Zona 1-7)', color='lightgreen')

# Adding labels and title
plt.xlabel('Mes')
plt.ylabel('Total en Invasiones')
plt.title('Distribución de Invasiones a Refrigeradores por Mes (Zona 1-7)')
plt.xticks(x, mes)
plt.legend(title='Invasiones')
plt.show()
